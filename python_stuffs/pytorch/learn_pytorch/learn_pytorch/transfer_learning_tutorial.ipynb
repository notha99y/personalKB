# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

plt.ion()   # interactive mode

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = 'data/hymenoptera_data'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)
                print('Checking')
                print(inputs.shape, labels)
                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# train Loss: 0.6375 Acc: 0.6680
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([1, 3, 224, 224]) tensor([1], device='cuda:0')
# val Loss: 0.3424 Acc: 0.8758
#
# Epoch 1/24
# ----------
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# train Loss: 0.4771 Acc: 0.7992
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([1, 3, 224, 224]) tensor([0], device='cuda:0')
# val Loss: 0.3151 Acc: 0.8235
#
# Epoch 2/24
# ----------
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# train Loss: 0.5682 Acc: 0.7418
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([1, 3, 224, 224]) tensor([1], device='cuda:0')
# val Loss: 0.5975 Acc: 0.7908
#
# Epoch 3/24
# ----------
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# train Loss: 0.4225 Acc: 0.8197
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([1, 3, 224, 224]) tensor([0], device='cuda:0')
# val Loss: 0.2721 Acc: 0.9085
#
# Epoch 4/24
# ----------
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# train Loss: 0.5536 Acc: 0.8074
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([1, 3, 224, 224]) tensor([0], device='cuda:0')
# val Loss: 0.3165 Acc: 0.9150
#
# Epoch 5/24
# ----------
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# train Loss: 0.5181 Acc: 0.7623
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([1, 3, 224, 224]) tensor([1], device='cuda:0')
# val Loss: 0.4961 Acc: 0.8562
#
# Epoch 6/24
# ----------
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# ...
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# train Loss: 0.3577 Acc: 0.8484
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([1, 3, 224, 224]) tensor([0], device='cuda:0')
# val Loss: 0.2915 Acc: 0.9216
#
# Epoch 12/24
# ----------
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# train Loss: 0.2818 Acc: 0.8566
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 0, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([1, 1, 1, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 0, 1], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 0, 0, 0], device='cuda:0')
# Checking
# torch.Size([4, 3, 224, 224]) tensor([0, 1, 1, 1], device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-cc88ea5f8bd3> in <module>
#       1 model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
# ----> 2                        num_epochs=25)
#
# <ipython-input-4-4a64c1557f07> in train_model(model, criterion, optimizer, scheduler, num_epochs)
#      20
#      21             # Iterate over data.
# ---> 22             for inputs, labels in dataloaders[phase]:
#      23                 inputs = inputs.to(device)
#      24                 labels = labels.to(device)
#
# ~/anaconda3/envs/learn_pytorch/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/envs/learn_pytorch/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     839
#     840             assert not self._shutdown and self._tasks_outstanding > 0
# --> 841             idx, data = self._get_data()
#     842             self._tasks_outstanding -= 1
#     843
#
# ~/anaconda3/envs/learn_pytorch/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#     806         else:
#     807             while True:
# --> 808                 success, data = self._try_get_data()
#     809                 if success:
#     810                     return data
#
# ~/anaconda3/envs/learn_pytorch/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     759         #   (bool: whether successfully get data, any: data if successful else None)
#     760         try:
# --> 761             data = self._data_queue.get(timeout=timeout)
#     762             return (True, data)
#     763         except Exception as e:
#
# ~/anaconda3/envs/learn_pytorch/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#     102                 if block:
#     103                     timeout = deadline - time.monotonic()
# --> 104                     if not self._poll(timeout):
#     105                         raise Empty
#     106                 elif not self._poll():
#
# ~/anaconda3/envs/learn_pytorch/lib/python3.7/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# ~/anaconda3/envs/learn_pytorch/lib/python3.7/multiprocessing/connection.py in _poll(self, timeout)
#     412
#     413     def _poll(self, timeout):
# --> 414         r = wait([self], timeout)
#     415         return bool(r)
#     416
#
# ~/anaconda3/envs/learn_pytorch/lib/python3.7/multiprocessing/connection.py in wait(object_list, timeout)
#     918
#     919             while True:
# --> 920                 ready = selector.select(timeout)
#     921                 if ready:
#     922                     return [key.fileobj for (key, events) in ready]
#
# ~/anaconda3/envs/learn_pytorch/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:
